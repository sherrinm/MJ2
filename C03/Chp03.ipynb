# %%
## We can define these here as as required
using BenchmarkTools, Match, PyPlot

# %%
# We need these as some functions have moved from Base to Stdlib
#
using Printf, LinearAlgebra, StaticArrays

# %% [markdown]
# ## Chapter 3

# %% [markdown]
# ### Collatz conjecture
#
# The Hailstone sequence of numbers can be generated from a starting positive integer, n by:
#
# - If n is 1 then the sequence ends.
# - If n is even then the next n of the sequence = n/2
# - If n is odd then the next n of the sequence = (3 * n) + 1
#
# The Collatz conjecture is that the hailstone sequence for any starting number always terminates.

# %%
function hailstone(n)
   k = 1
   a = [n]
   while n > 1 
      n = (n % 2 == 0) ? n >> 1 : 3n + 1 
      push!(a,n)
      k += 1
   end
   a
end
# Out:
# hailstone (generic function with 1 method)

# %%
hailstone(17)
# Out:
# 13-element Array{Int64,1}:
#  17
#  52
#  26
#  13
#  40
#  20
#  10
#   5
#  16
#   8
#   4
#   2
#   1

# %% [markdown]
# ---

# %%
using PyPlot

f(x, p = 0.0) = exp(p*x)*sin(x);
t = range(0.0,stop=8.0*π,length=101);
w = zeros(length(t));
for i = 1:length(w) w[i] = f(t[i], 0.1) end

plot(t, w)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f82c0b35130>

# %% [markdown]
# ---
#
# ### Pattern Matching

# %%
using Match

# %%
allodds(x) = @match x begin
    m::Int, if iseven(m) || (m < 3) end        => "Not a valid choice"
    n::Int, if n == 3 || n == 5 || n == 7 end  => "$x is prime"
    _  =>  "By induction all numbers are prime"
end
# Out:
# allodds (generic function with 1 method)

# %%
allodds(3)
# Out:
# "3 is prime"

# %%
allodds(6)
# Out:
# "Not a valid choice"

# %%
allodds(9)
# Out:
# "By induction all numbers are prime"

# %% [markdown]
# ## Solve Queens problem

# %%
struct Queen
    x::Int
    y::Int
end

# %%
qhorz(qa, qb) = qa.x == qb.x;
qvert(qa, qb) = qa.y == qb.y;
qdiag(qa, qb) = abs(qa.x - qb.x) == abs(qa.y - qb.y);

qhvd(qa, qb) = qhorz(qa, qb) || qvert(qa, qb) || qdiag(qa, qb);
qany(testq, qs) = any(q -> qhvd(testq, q), qs);

# %%
function qsolve(nsqsx, nsqsy, nqs, presqs = ())
    nqs == 0 && return presqs
    for xsq in 1:nsqsx
        for ysq in 1:nsqsy
            testq = Queen(xsq, ysq)
            if !qany(testq, presqs)
                tryqs = (presqs..., testq)
                maybe = qsolve(nsqsx, nsqsy, nqs - 1, tryqs)
                maybe !== nothing && return maybe
            end
        end
    end
    return nothing
end

qsolve(nqs) = qsolve(nqs, nqs, nqs)
# Out:
# qsolve (generic function with 3 methods)

# %%
qsolve(8)
# Out:
# (Queen(1, 1), Queen(2, 5), Queen(3, 8), Queen(4, 6), Queen(5, 3), Queen(6, 7), Queen(7, 2), Queen(8, 4))

# %% [markdown]
# ---

# %%
module Vehicles

export Contact, Vehicle, Car, Bike, Yacht, Powerboat, Boat
export Ford, BMW, VW, Scooter, MotorBike, Speedboat 

const KNOTS_TO_MPH = 1.151
       
struct Contact
    name::String
    email::String
    phone::String
end
                             
abstract type Vehicle end

abstract type Car <: Vehicle end
abstract type Bike <: Vehicle  end
abstract type Boat <: Vehicle end

abstract type Powerboat <: Boat end
       
struct Ford <: Car
    owner::Contact
    make::String
    fuel::String
    color::String
    engine_cc::Int64
    speed_mph::Float64
    function Ford(owner, make, engine_cc,speed_mph)
        new(owner,make,"Petrol","Black",engine_cc,speed_mph)
     end
end
       
struct BMW <: Car
    owner::Contact
    make::String
    fuel::String
    color::String
    engine_cc::Int64
    speed_mph::Float64
    function BMW(owner,make,engine_cc,speed_mph)
        new(owner,make,"Petrol","Blue",engine_cc,speed_mph)
   end
end
       
struct VW <: Car
    owner::Contact
    make::String
    fuel::String
    color::String
    engine_cc::Int64
    speed_mph::Float64
end

struct MotorBike <: Bike
    owner::Contact
    make::String
    engine_cc::Int64
    speed_mph::Float64
end
       
struct Scooter <: Bike
    owner::Contact
    make::String
    engine_cc::Int64
    speed_mph::Float64
end

mutable struct Yacht <: Boat
    owner::Contact
    make::String
    length_m::Float64
end
              
mutable struct Speedboat <: Powerboat
    owner::Contact
    make::String
    fuel::String
    engine_cc::Int64
    speed_knots::Float64
    length_m::Float64
end

function is_quicker(a::VW, b::BMW)
   if (a.speed_mph == b.speed_mph) 
      return nothing
    else
      return(a.speed_mph > b.speed_mph ? a : b)
     end
end

function is_quicker(a::Speedboat, b::Scooter)
   a_mph = KNOTS_TO_MPH * a.speed_knots
   if (a_mph == b.speed_mph) 
       return nothing
    else
       return(a_mph > b.speed_mph ? a : b)
    end
end

function is_longer(a::Yacht, b::Speedboat)
   if (a.length_m == b.length_m) 
       return nothing
    else
       return(a.length > b.length_m ? a : b)
    end
end

is_quicker(a::BMW, b::VW) = is_quicker(b,a)
is_quicker(a::Scooter, b::Speedboat) = is_quicker(b,a)
is_longer(a::Speedboat, b::Yacht) = is_longer(b,a)

end
# Out:
# Main.Vehicles

# %%
using Main.Vehicles;

malcolm = Contact("Malcolm","malcolm@abc.net","07777555999");
myCar = Ford(malcolm, "Model T", 1000, 50.0);
myBike = Scooter(malcolm, "Vespa", 125, 35.0);

james = Contact("James","james@abc.net","07777666888");
jmCar = BMW(james,"Series 500", 3200, 125.0);
jmBoat = Yacht(james,"Oceanis 44",14.6);
jmBike = MotorBike(james, "Harley", 850, 120.0);

david = Contact("David","dave@abc.net","07777222444");
dvCar = VW(david,"Golf", "diesel", "red", 1800, 85.0);
dvBoat = Speedboat(david,"Sealine","petrol", 600, 45.0, 8.2);

# %%
myCar.owner = david

# %%
dvBoat.owner = malcolm

# %%
s = [myCar, jmCar, dvCar]
for c in s
    who = c.owner.name
    model = c.make
    println("$who has a $model car")
end
# Out:
# Malcolm has a Model T car
# James has a Series 500 car
# David has a Golf car

# %%
# Note that Malcolm now owns Dave's boat
#
s =[dvCar, dvBoat]  
for c in s
    who = c.owner.name
    model = c.make
    println("$who has a $model vehicle")
end
# Out:
# David has a Golf vehicle
# David has a Sealine vehicle

# %%
println("James owns these vehicles: ")
s = [jmCar, jmBike, jmBoat] 
for c in s
    println("....\t$(c.make)")
end
# Out:
# James owns these vehicles:
# ....	Series 500
# ....	Harley
# ....	Oceanis 44

# %%
# Make this mutable as I might change where I live
#
mutable struct Address
  name::String
  street::String
  city::String
  country::String
  postcode::String
end

# %%
postal = Address("Malcolm Sherrington","1 Main Street", "London", "UK", "WC2N 9ZZ");

# %%
const Owner = Union{Contact, Address}
# Out:
# Union{Address, Contact}

# %%
struct Skiff <: Boat
   owner::Owner
   make::String
   length_m::Float64
end

# %%
y1 = Skiff(malcolm,"Moody 36", 11.02)
# Out:
# Skiff(Contact("Malcolm", "malcolm@abc.net", "07777555999"), "Moody 36", 11.02)

# %%
y2 = Skiff(postal,"Dufour 44", 13.47)
# Out:
# UndefVarError: postal not defined
#
# Stacktrace:
#  [1] top-level scope at In[25]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
@assert y1.length_m < y2.length_m
# Out:
# UndefVarError: y2 not defined
#
# Stacktrace:
#  [1] top-level scope at In[26]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### 3D vectors
#
# ---

# %%
# This module uses Float64 components but could use a parameterised type {T}
#
module V3D

# import Base.+, Base.*, Base./, Base.==, Base.<, Base.>
#
import Base: +, *, /, ==, <, >, zero, one
import LinearAlgebra: norm, dot

export Vec3, norm, dist, zero, one

struct Vec3
    x::Float64
    y::Float64
    z::Float64
end

(+)(a::Vec3, b::Vec3) = Vec3(a.x+b.x, a.y+b.y, a.z+b.z)
(*)(p::Vec3, s::Real) = Vec3(p.x*s, p.y*s, p.z*s)
(*)(s::Real, p::Vec3) = p*s
(/)(p::Vec3, s::Real) = (1.0/s)*p

(==)(a::Vec3, b::Vec3) = (a.x==b.x)&&(a.y==b.y)&&(a.z==b.z) ? true : false;

dot(a::Vec3, b::Vec3) = a.x*b.x + a.y*b.y + a.z*b.z;
norm(a::Vec3) = sqrt(dot(a,a));

zero(a::Vec3) = Vec3(0.0,0.0,0.0);
one(a::Vec3)  = Vec3(1.0,1.0,1.0);

(<)(a::Vec3, b::Vec3) = norm(a) < norm(b) ? true : false;
(>)(a::Vec3, b::Vec3) = norm(a) > norm(b) ? true : false;

dist(a::Vec3, b::Vec3) = sqrt((a.x-b.x)*(a.x-b.x) + (a.y-b.y)*(a.y-b.y) + (a.z-b.z)*(a.z-b.z))

end
# Out:
# Main.V3D

# %%
using Main.V3D
using Printf

v1 = Vec3(1.2,3.4,5.6);
v2 = Vec3(2.1,4.3,6.5);
@printf "Distance between vectors is %.3f \n" dist(v1,v2)
# Out:
# Distance between vectors is 1.559

# %%
vv = [Vec3(rand(),rand(),rand()) for i = 1:1000000];
vs = reshape(vv,1000,1000)
# Out:
# 1000×1000 Array{Vec3,2}:
#  Vec3(0.0799121, 0.630181, 0.118081)  …  Vec3(0.0490923, 0.731341, 0.323357)
#  Vec3(0.782254, 0.377706, 0.20421)       Vec3(0.650551, 0.390153, 0.0780684)
#  Vec3(0.523477, 0.634898, 0.36631)       Vec3(0.793824, 0.344474, 0.257428)
#  Vec3(0.28963, 0.750631, 0.00982481)     Vec3(0.125255, 0.769295, 0.41541)
#  Vec3(0.647916, 0.809153, 0.281258)      Vec3(0.868092, 0.182855, 0.317066)
#  Vec3(0.718831, 0.712515, 0.610844)   …  Vec3(0.20772, 0.476601, 0.511981)
#  Vec3(0.333971, 0.778992, 0.400003)      Vec3(0.481651, 0.665005, 0.637762)
#  Vec3(0.386046, 0.504907, 0.695145)      Vec3(0.237933, 0.23868, 0.0643395)
#  Vec3(0.668788, 0.522461, 0.630455)      Vec3(0.702156, 0.553261, 0.989096)
#  Vec3(0.293098, 0.81355, 0.749927)       Vec3(0.373935, 0.599912, 0.292749)
#  Vec3(0.883799, 0.221052, 0.311095)   …  Vec3(0.975118, 0.986138, 0.295368)
#  Vec3(0.304513, 0.0194849, 0.934464)     Vec3(0.727337, 0.0628893, 0.842301)
#  Vec3(0.969679, 0.933646, 0.9731)        Vec3(0.763755, 0.890109, 0.333334)
#  ⋮                                    ⋱
#  Vec3(0.676319, 0.647415, 0.453784)      Vec3(0.0500813, 0.518568, 0.388689)
#  Vec3(0.674504, 0.23729, 0.114393)       Vec3(0.344539, 0.0284217, 0.335919)
#  Vec3(0.296687, 0.0355615, 0.188611)  …  Vec3(0.300968, 0.408274, 0.370318)
#  Vec3(0.403546, 0.171548, 0.0265152)     Vec3(0.19091, 0.649384, 0.020066)
#  Vec3(0.356922, 0.304038, 0.214571)      Vec3(0.460707, 0.606955, 0.791276)
#  Vec3(0.354422, 0.0946239, 0.436127)     Vec3(0.528834, 0.644122, 0.922095)
#  Vec3(0.79595, 0.377712, 0.210318)       Vec3(0.960469, 0.774445, 0.969818)
#  Vec3(0.720899, 0.733911, 0.26001)    …  Vec3(0.39697, 0.628696, 0.603862)
#  Vec3(0.590042, 0.332308, 0.385481)      Vec3(0.687835, 0.771261, 0.0100286)
#  Vec3(0.645505, 0.18058, 0.530922)       Vec3(0.840352, 0.679612, 0.608937)
#  Vec3(0.791149, 0.678257, 0.931059)      Vec3(0.336082, 0.818063, 0.862503)
#  Vec3(0.0122107, 0.105491, 0.803566)     Vec3(0.316856, 0.190401, 0.251036)

# %%
using LinearAlgebra

dv = map(v -> norm(v), vs)
dw = dv'
ee = eigen(dw)
# Out:
# Eigen{Complex{Float64},Complex{Float64},Array{Complex{Float64},2},Array{Complex{Float64},1}}
# values:
# 1000-element Array{Complex{Float64},1}:
#  -8.554350109510871 - 1.9967872743995538im
#  -8.554350109510871 + 1.9967872743995538im
#  -8.549024553276386 - 0.2566497637040594im
#  -8.549024553276386 + 0.2566497637040594im
#  -8.356734913745568 - 1.4536529783218681im
#  -8.356734913745568 + 1.4536529783218681im
#  -8.187953488838758 + 0.0im
#   -8.16419595390743 - 1.1007886824071502im
#   -8.16419595390743 + 1.1007886824071502im
#  -8.134444867213094 - 2.7676678779990067im
#  -8.134444867213094 + 2.7676678779990067im
#  -8.087431886574297 - 1.8613124317428338im
#  -8.087431886574297 + 1.8613124317428338im
#                     ⋮
#    8.13271586085875 + 1.4651486379185779im
#   8.249107546639708 - 2.306016700863404im
#   8.249107546639708 + 2.306016700863404im
#   8.389950531484917 - 1.0779791086211628im
#   8.389950531484917 + 1.0779791086211628im
#   8.543289738662331 - 0.478382329976874im
#   8.543289738662331 + 0.478382329976874im
#   8.568888398159837 - 1.9067466695468567im
#   8.568888398159837 + 1.9067466695468567im
#    8.85835277365102 - 0.46684150677043496im
#    8.85835277365102 + 0.46684150677043496im
#   960.3873802472013 + 0.0im
# vectors:
# 1000×1000 Array{Complex{Float64},2}:
#    0.0209372-0.0495881im     0.0209372+0.0495881im   …  -0.0312424+0.0im
#    0.0369898-0.0197771im     0.0369898+0.0197771im      -0.0307194+0.0im
#    0.0358457+0.00734452im    0.0358457-0.00734452im     -0.0312391+0.0im
#  -0.00157271+0.0388147im   -0.00157271-0.0388147im      -0.0317193+0.0im
#  -0.00136677-0.0067799im   -0.00136677+0.0067799im      -0.0313735+0.0im
#   -0.0105827+0.0149904im    -0.0105827-0.0149904im   …  -0.0312324+0.0im
#   -0.0185959-0.00914892im   -0.0185959+0.00914892im     -0.0318334+0.0im
#    0.0206792-0.00649209im    0.0206792+0.00649209im     -0.0318936+0.0im
#   -0.0100269-0.0205328im    -0.0100269+0.0205328im      -0.0313047+0.0im
#   -0.0130522-0.00280551im   -0.0130522+0.00280551im      -0.031381+0.0im
#    0.0274113-0.00126299im    0.0274113+0.00126299im  …  -0.0316951+0.0im
#    0.0145224+0.025221im      0.0145224-0.025221im       -0.0316012+0.0im
#   0.00401607-0.0121767im    0.00401607+0.0121767im      -0.0317627+0.0im
#             ⋮                                        ⋱
#    0.0210883+0.0713028im     0.0210883-0.0713028im      -0.0317372+0.0im
#   -0.0432394-0.0103241im    -0.0432394+0.0103241im      -0.0313895+0.0im
#     -0.02467+0.0135711im      -0.02467-0.0135711im   …  -0.0324639+0.0im
#   -0.0297377-0.0153987im    -0.0297377+0.0153987im      -0.0322945+0.0im
#    0.0104148+0.0166559im     0.0104148-0.0166559im      -0.0317236+0.0im
#    0.0106642+0.0307594im     0.0106642-0.0307594im       -0.031407+0.0im
#    0.0103231-0.00160039im    0.0103231+0.00160039im     -0.0323609+0.0im
#  -0.00547441-0.016628im    -0.00547441+0.016628im    …   -0.031484+0.0im
#   -0.0276176-0.0570247im    -0.0276176+0.0570247im      -0.0322307+0.0im
#     0.020296-0.0267394im      0.020296+0.0267394im      -0.0316028+0.0im
#   -0.0258313-0.01927im      -0.0258313+0.01927im         -0.031341+0.0im
#   0.00703866-0.0138279im    0.00703866+0.0138279im      -0.0318735+0.0im

# %%
k = 0
for i in 1:length(vv)
  if norm(vv[i]) < 1.0 
    global k +=1 
  end
end
@printf "Estimate of PI is %9.5f\n" 6.0*k/length(vv)
# Out:
# Estimate of PI is   3.14654

# %%
#
# Defining the Vec3 parameterically and the rest of the module is unchanged
# i.e.
#
# immutable Vec3P{T}
#    x::T
#    y::T
#    z::T
# end
#
module V3P
#
# import Base.+, Base.*, Base./, Base.norm, Base.==, Base.<, Base.>
#
import Base: +, *, /, ==, <, >
import LinearAlgebra: norm, dot
export Vec3P, norm, distp

struct Vec3P{T}
    x::T
    y::T
    z::T
end

(+)(a::Vec3P, b::Vec3P) = Vec3P(a.x+b.x, a.y+b.y, a.z+b.z)
(*)(p::Vec3P, s::Real) = Vec3P(p.x*s, p.y*s, p.z*s)
(*)(s::Real, p::Vec3P) = p*s
(/)(p::Vec3P, s::Real) = (1.0/s)*p

(==)(a::Vec3P, b::Vec3P) = (a.x==b.x)&&(a.y==b.y)&&(a.z==b.z) ? true : false;

dot(a::Vec3P, b::Vec3P) = a.x*b.x + a.y*b.y + a.z*b.z;
norm(a::Vec3P) = sqrt(dot(a,a));

(<)(a::Vec3P, b::Vec3P) = norm(a) < norm(b) ? true : false;
(>)(a::Vec3P, b::Vec3P) = norm(a) > norm(b) ? true : false;

distp(a::Vec3P, b::Vec3P) = sqrt((a.x-b.x)*(a.x-b.x) + (a.y-b.y)*(a.y-b.y) + (a.z-b.z)*(a.z-b.z))

end
# Out:
# Main.V3P

# %%
using Main.V3P

z1 = Vec3P{Complex}(1+2im,2+3im,3+4im);
z2 = Vec3P{Complex}(3-2im,4-3im,5-4im);
z1 + z2
# Out:
# Vec3P{Complex{Int64}}(4 + 0im, 6 + 0im, 8 + 0im)

# %%
zn = norm(z1 + z2)        # => sqrt(116) but IS a complex number.
@assert zn == sqrt(116)

# Notice that the vaule is returned as a complex.
zn
# Out:
# 10.770329614269007 + 0.0im

# %%
r1 = Vec3P{Rational}(11//7,13//5,8//17)
r2 = Vec3P{Rational}(17//9,23//15,28//17)
r1 + r2
# Out:
# Vec3P{Rational{Int64}}(218//63, 62//15, 36//17)

# %%
# Norm is promoted to a Real as it can not be represented as a Rational
#
norm(r1 + r2)
# Out:
# 5.791603442602598

# %% [markdown]
# ---
#
# ### It is possible to extend the above to an *nD* vector simply using static arrays.
#
# ---

# %%
module VNX
using StaticArrays

import Base: +, *, /, ==, <, >
import LinearAlgebra: norm, dot
export VecN, norm, distx

struct VecN
    sv::SVector;
end

sizeof(a::VecN) = length(a.sv)
sOK(a::VecN, b::VecN) = 
 (sizeof(a) == sizeof(b)) ? true : throw(BoundsError("Vector of different lengths"));

(+)(a::VecN, b::VecN) = [a.sv[i] + b.sv[i] for i in 1:sizeof(a) if sOK(a,b)]
(*)(x::Real, a::VecN) = [a.sv[i]*x for i in 1:sizeof(a)]
(*)(a::VecN, x::Real) = x*a
(/)(a::VecN, x::Real) = [a.sv[i]/x for i in 1:sizeof(a)]

(==)(a::VecN, b::VecN) = any([(a.sv[i] == b.sv[i]) for i in 1:sizeof(a) if sOK(a,b)])
                            
dot(a::VecN, b::VecN) = sum([a.sv[i]*b.sv[i] for i in 1:sizeof(a) if sOK(a,b)])
norm(a::VecN) = sqrt(dot(a,a));

(<)(a::VecN, b::VecN) = norm(a) < norm(b) ? true : false;
(>)(a::VecN, b::VecN) = norm(a) > norm(b) ? true : false;                                            
                                            
distx(a::VecN, b::VecN) = sum(map(x -> x*x,[a.sv[i]-b.sv[i] for i in 1:sizeof(a) if sOK(a,b)]))

end
# Out:
# Main.VNX

# %%
# Generate K 4-vectors
#
using Main.VNX, StaticArrays

K = 10^5; 
vv = Array{VecN}(undef,K);

for j = 1:K
  vv[j] =  VecN(@SVector [rand() for i = 1:4])
end

# %%
# Sum up the vectors which lie within the 4-ball
#
s = 0;
for j = 1:K 
  if (norm(vv[j]) < 1.0) s += 1 end
end

# %%
# Volume of the unit 4-ball is 2*π*π
# The count is 1/16th of the volume
# 
mypi = sqrt(32*s/K)
# Out:
# 3.136928433993992
